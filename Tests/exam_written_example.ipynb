# %% [markdown]
# <center><h1>Exemple d'examen écrit</h1></center>
#
# <b>Note : </b> L'examen sera sur feuille papier et non sur un notebook jupyter

# %% [markdown]
# # Exercice 1:
# Analyser le code suivant et identifier les erreurs de syntaxe.
# Utilisez les numéros des lignes pour localiser les erreurs et décrivez les erreurs.
#
# ```
# 1   class Calculator:
# 2
# 3       def __init__(self):
# 4           result = 0
# 5
# 6       def add(self, num):
# 7           self.res += num
# 8
# 9       def subtract(num):
# 10          self.result -= num
# 11
# 12      def multiply(self, num)
# 13          self.result *= num
# 14
# 15      def display_result(self):
# 16          print("Result: " + result)
# 17
# 18
# 19   # Using the calculator
# 20   calc = Calculator
# 21   calc.add(5)
# 22   calc.subtract(3)
# 23   calc.multiply(2)
# 24   calc.display_result
# ```

# %% [markdown]
# # Exercice 2:
# Analyser le code suivant et identifier les erreurs de syntaxe.
# Utilisez les numéros des lignes pour localiser les erreurs et décrivez les erreurs.
#
# ```
# 1    class Shape:
# 2
# 3        def __init__(self, name):
# 4            self.__name = name
# 5
# 6
# 7    class Circle(Shape):
# 8
# 9        def __init__(self, radius):
# 10           super().__init__("circle")
# 11           radius = radius
# 12
# 13       def area(self):
# 14           super().area()
# 15           return 3.14 * self.radius * self.radius
# 16
# 17
# 18   # Using the classes
# 19   circle = Circle(5)
# 20   Circle.area(circle)
# 21   print(f"Area of {circle.__name} is {circle.area()}")
# ```

# %% [markdown]
# # Exercice 3
# - Analyser le code suivant et identifier les constante(s), les attribut(s) et les argument(s).
#     - Constante(s):
#     - Attribut(s):
#     - Argument(s):
# - Identifier les méthode(s) et les fonction(s).
#     - Méthode(s):
#     - Fonction(s)
# - Identifier les classes et les instances de classe(s)/objet(s).
#     - Classe(s):
#     - Objet(s):
# - Que fait le code?
#
# <br/><br/><br/>
#
# ```
# 1    VAT = 0.20
# 2
# 3
# 4    def apply_vat(price):
# 5        return price + (price * VAT)
# 6
# 7
# 8    class Product:
# 9
# 10       def __init__(self, name, price, quantity):
# 11           self.name = name
# 12           self._price = price
# 13           self._quantity = quantity
# 14
# 15       def update_price(self, new_price):
# 16           self._price = new_price
# 17
# 18       def add_quantity(self, quantity_to_add):
# 19           self._quantity += quantity_to_add
# 20
# 21       def remove_quantity(self, quantity_to_remove):
# 22           self._quantity -= quantity_to_remove
# 23
# 24       def display_info(self):
# 25           price_with_vat = apply_vat(self._price)
# 26           print(f"Product: {self.name}, Price with VAT: {price_with_vat} €")
# 27
# 28
# 29   # Testing script
# 30   product_phone = Product("Phone", 100, 10)
# 31   product_laptop = Product("Laptop", 500, 5)
# 32
# 33   product_phone.update_price(200)
# 34   product_phone.display_info()
# ```

# %% [markdown]
# # Exercice 4
# Quelles seront les valeurs finales des attributs de phone1, phone2 et phone3 en exécutant ce script?
#
# ```
# 1    class Phone:
# 2        def __init__(self, brand):
# 3            self.brand = brand
# 4            self.battery_level = 0
# 5
# 6        def charge(self, increase):
# 7            self.battery_level += increase
# 8            if self.battery_level > 100:
# 9                self.battery_level = 100
# 10
# 11       def use(self, decrease):
# 12           self.battery_level -= decrease
# 13           if self.battery_level < 0:
# 14               self.battery_level = 0
# 15
# 16
# 17   phone1 = Phone("Samsung")
# 18   phone2 = Phone("iPhone")
# 19   phone3 = Phone("Nokia")
# 20
# 21   phone1.charge(120)
# 22   phone1.use(100)
# 23
# 24   phone2.charge(50)
# 25   phone2.use(30)
# 26
# 27   phone3.charge(40)
# 28   phone3.use(60)
# ```

# %% [markdown]
# # Exercice 5:
# Lorsque que l'on va exécuter ce script, quel sera l'ordre des messages affichées.
# Lister de cette manière A -> F -> ...
#
# ```
# 1    class Vehicle:
# 2        def __init__(self, vehicle_type):
# 3            self.type = vehicle_type
# 4            print(f"Message A: {self.type} created.")
# 5
# 6        def start(self):
# 7            print(f"Message B: The {self.type} is starting.")
# 8
# 9    class Car(Vehicle):
# 10       def __init__(self, brand):
# 11           super().__init__("Car")
# 12           self.brand = brand
# 13           print(f"Message C: Car of brand {self.brand} created.")
# 14
# 15       def honk(self):
# 16           print(f"Message D: The {self.brand} is honking.")
# 17
# 18   class Truck(Vehicle):
# 19       def __init__(self, capacity):
# 20           super().__init__("Truck")
# 21           self.capacity = capacity
# 22           print(f"Message E: Truck with a capacity of {self.capacity} tons created.")
# 23
# 24       def load(self, weight):
# 25           if weight <= self.capacity:
# 26               print(f"Message F: Loading {weight} tons.")
# 27           else:
# 28               print("Message G: Cannot load, overweight!")
# 29
# 30
# 31   car1 = Car("Subaru")
# 32   car1.start()
# 33   car1.honk()
# 34
# 35   truck1 = Truck(10)
# 36   truck1.start()
# 37   truck1.load(7)
# 38   truck1.load(12)
#
# ```

# %% [markdown]
# # Exercice 6:
# Écrivez le code des classes "Vehicle" et "Car".
# - La classe "Vehicle" possède deux attributs : "fuel" initialisé à 100 et "distance_travelled" initialisé à 0.
# - La classe "Car" hérite de la classe "Vehicle".
# - La classe "Car" possède une méthode "drive" qui prend un argument "distance". Pour chaque unité de distance parcourue, le "fuel" est réduit de 1 et "distance_travelled" est augmenté de 1. Si le "fuel" atteint 0, le véhicule ne peut plus avancer et un message est affiché : "Out of fuel, can't drive further". (Pensez à utiliser une boucle while qui check l'argument distance et l'attribut fuel)
# - La classe "Car" possède également une méthode "refuel" qui remet le "fuel" à 100.

# %% [markdown]
# # Exercice 7:
# 1. En programmation orientée objet, que signifie le terme 'abstraction' ?
#
# 1. Qu'est-ce que le mot-clé 'super' en programmation orientée objet, et quand l'utilise-t-on ?
#
# 1. Comment puis-je voir l'ensemble des attributs et méthodes d'un objet en Python ?
#
# 1. Dans la méthode method1 de cette classe, que représente le premier argument 'self' ?
#
# ```
# 1   class MyClass:
# 2       def __init__(self, value1):
# 3           self.attribute1 = value1
# 4
# 5       def method1(self):
# 6           return self.attribute1 * 2
# ```
